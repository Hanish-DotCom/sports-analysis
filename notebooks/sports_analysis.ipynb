# %% [markdown]
# # sports analysis

# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt 
import seaborn as sn
import duckdb as db

# %%
connection = db.connect()
connection.register( '', df)
